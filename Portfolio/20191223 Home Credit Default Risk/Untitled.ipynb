# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_raw = pd.read_csv('data/train.csv')
X_test = pd.read_csv('data/test.csv')

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(df_raw.tail().transpose())
# Out:
#                                                      307506  \
# SK_ID_CURR                                           456251
# TARGET                                                    0
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               M
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           N
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                     157500
# AMT_CREDIT                                           254700
# AMT_ANNUITY                                           27558
# AMT_GOODS_PRICE                                      225000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                    Working
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                                Separated
# NAME_HOUSING_TYPE                              With parents
# REGION_POPULATION_RELATIVE                         0.032561
# DAYS_BIRTH                                            -9327
# DAYS_EMPLOYED                                          -236
# DAYS_REGISTRATION                                     -8456
# DAYS_ID_PUBLISH                                       -1982
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                0
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                 Sales staff
# CNT_FAM_MEMBERS                                           1
# REGION_RATING_CLIENT                                      1
# REGION_RATING_CLIENT_W_CITY                               1
# WEEKDAY_APPR_PROCESS_START                         THURSDAY
# HOUR_APPR_PROCESS_START                                  15
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                                  Services
# EXT_SOURCE_1                                        0.14557
# EXT_SOURCE_2                                       0.681632
# EXT_SOURCE_3                                            NaN
# APARTMENTS_AVG                                       0.2021
# BASEMENTAREA_AVG                                     0.0887
# YEARS_BEGINEXPLUATATION_AVG                          0.9876
# YEARS_BUILD_AVG                                        0.83
# COMMONAREA_AVG                                       0.0202
# ELEVATORS_AVG                                          0.22
# ENTRANCES_AVG                                        0.1034
# FLOORSMAX_AVG                                        0.6042
# FLOORSMIN_AVG                                        0.2708
# LANDAREA_AVG                                         0.0594
# LIVINGAPARTMENTS_AVG                                 0.1484
# LIVINGAREA_AVG                                       0.1965
# NONLIVINGAPARTMENTS_AVG                              0.0753
# NONLIVINGAREA_AVG                                    0.1095
# APARTMENTS_MODE                                      0.1008
# BASEMENTAREA_MODE                                    0.0172
# YEARS_BEGINEXPLUATATION_MODE                         0.9782
# YEARS_BUILD_MODE                                     0.7125
# COMMONAREA_MODE                                      0.0172
# ELEVATORS_MODE                                       0.0806
# ENTRANCES_MODE                                       0.0345
# FLOORSMAX_MODE                                       0.4583
# FLOORSMIN_MODE                                       0.0417
# LANDAREA_MODE                                        0.0094
# LIVINGAPARTMENTS_MODE                                0.0882
# LIVINGAREA_MODE                                      0.0853
# NONLIVINGAPARTMENTS_MODE                                  0
# NONLIVINGAREA_MODE                                   0.0125
# APARTMENTS_MEDI                                       0.204
# BASEMENTAREA_MEDI                                    0.0887
# YEARS_BEGINEXPLUATATION_MEDI                         0.9876
# YEARS_BUILD_MEDI                                     0.8323
# COMMONAREA_MEDI                                      0.0203
# ELEVATORS_MEDI                                         0.22
# ENTRANCES_MEDI                                       0.1034
# FLOORSMAX_MEDI                                       0.6042
# FLOORSMIN_MEDI                                       0.2708
# LANDAREA_MEDI                                        0.0605
# LIVINGAPARTMENTS_MEDI                                0.1509
# LIVINGAREA_MEDI                                      0.2001
# NONLIVINGAPARTMENTS_MEDI                             0.0757
# NONLIVINGAREA_MEDI                                   0.1118
# FONDKAPREMONT_MODE                         reg oper account
# HOUSETYPE_MODE                               block of flats
# TOTALAREA_MODE                                       0.2898
# WALLSMATERIAL_MODE                             Stone, brick
# EMERGENCYSTATE_MODE                                      No
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                 -273
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           0
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           1
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                              NaN
# AMT_REQ_CREDIT_BUREAU_DAY                               NaN
# AMT_REQ_CREDIT_BUREAU_WEEK                              NaN
# AMT_REQ_CREDIT_BUREAU_MON                               NaN
# AMT_REQ_CREDIT_BUREAU_QRT                               NaN
# AMT_REQ_CREDIT_BUREAU_YEAR                              NaN
#
#                                                      307507  \
# SK_ID_CURR                                           456252
# TARGET                                                    0
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               F
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                      72000
# AMT_CREDIT                                           269550
# AMT_ANNUITY                                         12001.5
# AMT_GOODS_PRICE                                      225000
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                                  Pensioner
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                                    Widow
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.025164
# DAYS_BIRTH                                           -20775
# DAYS_EMPLOYED                                        365243
# DAYS_REGISTRATION                                     -4388
# DAYS_ID_PUBLISH                                       -4090
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            0
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                1
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                         NaN
# CNT_FAM_MEMBERS                                           1
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                           MONDAY
# HOUR_APPR_PROCESS_START                                   8
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    0
# REG_CITY_NOT_WORK_CITY                                    0
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                                       XNA
# EXT_SOURCE_1                                            NaN
# EXT_SOURCE_2                                       0.115992
# EXT_SOURCE_3                                            NaN
# APARTMENTS_AVG                                       0.0247
# BASEMENTAREA_AVG                                     0.0435
# YEARS_BEGINEXPLUATATION_AVG                          0.9727
# YEARS_BUILD_AVG                                       0.626
# COMMONAREA_AVG                                       0.0022
# ELEVATORS_AVG                                             0
# ENTRANCES_AVG                                        0.1034
# FLOORSMAX_AVG                                        0.0833
# FLOORSMIN_AVG                                         0.125
# LANDAREA_AVG                                         0.0579
# LIVINGAPARTMENTS_AVG                                 0.0202
# LIVINGAREA_AVG                                       0.0257
# NONLIVINGAPARTMENTS_AVG                                   0
# NONLIVINGAREA_AVG                                         0
# APARTMENTS_MODE                                      0.0252
# BASEMENTAREA_MODE                                    0.0451
# YEARS_BEGINEXPLUATATION_MODE                         0.9727
# YEARS_BUILD_MODE                                     0.6406
# COMMONAREA_MODE                                      0.0022
# ELEVATORS_MODE                                            0
# ENTRANCES_MODE                                       0.1034
# FLOORSMAX_MODE                                       0.0833
# FLOORSMIN_MODE                                        0.125
# LANDAREA_MODE                                        0.0592
# LIVINGAPARTMENTS_MODE                                 0.022
# LIVINGAREA_MODE                                      0.0267
# NONLIVINGAPARTMENTS_MODE                                  0
# NONLIVINGAREA_MODE                                        0
# APARTMENTS_MEDI                                       0.025
# BASEMENTAREA_MEDI                                    0.0435
# YEARS_BEGINEXPLUATATION_MEDI                         0.9727
# YEARS_BUILD_MEDI                                      0.631
# COMMONAREA_MEDI                                      0.0022
# ELEVATORS_MEDI                                            0
# ENTRANCES_MEDI                                       0.1034
# FLOORSMAX_MEDI                                       0.0833
# FLOORSMIN_MEDI                                        0.125
# LANDAREA_MEDI                                        0.0589
# LIVINGAPARTMENTS_MEDI                                0.0205
# LIVINGAREA_MEDI                                      0.0261
# NONLIVINGAPARTMENTS_MEDI                                  0
# NONLIVINGAREA_MEDI                                        0
# FONDKAPREMONT_MODE                         reg oper account
# HOUSETYPE_MODE                               block of flats
# TOTALAREA_MODE                                       0.0214
# WALLSMATERIAL_MODE                             Stone, brick
# EMERGENCYSTATE_MODE                                      No
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                    0
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           1
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                              NaN
# AMT_REQ_CREDIT_BUREAU_DAY                               NaN
# AMT_REQ_CREDIT_BUREAU_WEEK                              NaN
# AMT_REQ_CREDIT_BUREAU_MON                               NaN
# AMT_REQ_CREDIT_BUREAU_QRT                               NaN
# AMT_REQ_CREDIT_BUREAU_YEAR                              NaN
#
#                                          307508  \
# SK_ID_CURR                               456253
# TARGET                                        0
# NAME_CONTRACT_TYPE                   Cash loans
# CODE_GENDER                                   F
# FLAG_OWN_CAR                                  N
# FLAG_OWN_REALTY                               Y
# CNT_CHILDREN                                  0
# AMT_INCOME_TOTAL                         153000
# AMT_CREDIT                               677664
# AMT_ANNUITY                               29979
# AMT_GOODS_PRICE                          585000
# NAME_TYPE_SUITE                   Unaccompanied
# NAME_INCOME_TYPE                        Working
# NAME_EDUCATION_TYPE            Higher education
# NAME_FAMILY_STATUS                    Separated
# NAME_HOUSING_TYPE             House / apartment
# REGION_POPULATION_RELATIVE             0.005002
# DAYS_BIRTH                               -14966
# DAYS_EMPLOYED                             -7921
# DAYS_REGISTRATION                         -6737
# DAYS_ID_PUBLISH                           -5150
# OWN_CAR_AGE                                 NaN
# FLAG_MOBIL                                    1
# FLAG_EMP_PHONE                                1
# FLAG_WORK_PHONE                               0
# FLAG_CONT_MOBILE                              1
# FLAG_PHONE                                    0
# FLAG_EMAIL                                    1
# OCCUPATION_TYPE                        Managers
# CNT_FAM_MEMBERS                               1
# REGION_RATING_CLIENT                          3
# REGION_RATING_CLIENT_W_CITY                   3
# WEEKDAY_APPR_PROCESS_START             THURSDAY
# HOUR_APPR_PROCESS_START                       9
# REG_REGION_NOT_LIVE_REGION                    0
# REG_REGION_NOT_WORK_REGION                    0
# LIVE_REGION_NOT_WORK_REGION                   0
# REG_CITY_NOT_LIVE_CITY                        0
# REG_CITY_NOT_WORK_CITY                        1
# LIVE_CITY_NOT_WORK_CITY                       1
# ORGANIZATION_TYPE                        School
# EXT_SOURCE_1                           0.744026
# EXT_SOURCE_2                           0.535722
# EXT_SOURCE_3                           0.218859
# APARTMENTS_AVG                           0.1031
# BASEMENTAREA_AVG                         0.0862
# YEARS_BEGINEXPLUATATION_AVG              0.9816
# YEARS_BUILD_AVG                          0.7484
# COMMONAREA_AVG                           0.0123
# ELEVATORS_AVG                                 0
# ENTRANCES_AVG                            0.2069
# FLOORSMAX_AVG                            0.1667
# FLOORSMIN_AVG                            0.2083
# LANDAREA_AVG                                NaN
# LIVINGAPARTMENTS_AVG                     0.0841
# LIVINGAREA_AVG                           0.9279
# NONLIVINGAPARTMENTS_AVG                       0
# NONLIVINGAREA_AVG                             0
# APARTMENTS_MODE                           0.105
# BASEMENTAREA_MODE                        0.0894
# YEARS_BEGINEXPLUATATION_MODE             0.9816
# YEARS_BUILD_MODE                         0.7583
# COMMONAREA_MODE                          0.0124
# ELEVATORS_MODE                                0
# ENTRANCES_MODE                           0.2069
# FLOORSMAX_MODE                           0.1667
# FLOORSMIN_MODE                           0.2083
# LANDAREA_MODE                               NaN
# LIVINGAPARTMENTS_MODE                    0.0918
# LIVINGAREA_MODE                          0.9667
# NONLIVINGAPARTMENTS_MODE                      0
# NONLIVINGAREA_MODE                            0
# APARTMENTS_MEDI                          0.1041
# BASEMENTAREA_MEDI                        0.0862
# YEARS_BEGINEXPLUATATION_MEDI             0.9816
# YEARS_BUILD_MEDI                         0.7518
# COMMONAREA_MEDI                          0.0124
# ELEVATORS_MEDI                                0
# ENTRANCES_MEDI                           0.2069
# FLOORSMAX_MEDI                           0.1667
# FLOORSMIN_MEDI                           0.2083
# LANDAREA_MEDI                               NaN
# LIVINGAPARTMENTS_MEDI                    0.0855
# LIVINGAREA_MEDI                          0.9445
# NONLIVINGAPARTMENTS_MEDI                      0
# NONLIVINGAREA_MEDI                            0
# FONDKAPREMONT_MODE             reg oper account
# HOUSETYPE_MODE                   block of flats
# TOTALAREA_MODE                            0.797
# WALLSMATERIAL_MODE                        Panel
# EMERGENCYSTATE_MODE                          No
# OBS_30_CNT_SOCIAL_CIRCLE                      6
# DEF_30_CNT_SOCIAL_CIRCLE                      0
# OBS_60_CNT_SOCIAL_CIRCLE                      6
# DEF_60_CNT_SOCIAL_CIRCLE                      0
# DAYS_LAST_PHONE_CHANGE                    -1909
# FLAG_DOCUMENT_2                               0
# FLAG_DOCUMENT_3                               1
# FLAG_DOCUMENT_4                               0
# FLAG_DOCUMENT_5                               0
# FLAG_DOCUMENT_6                               0
# FLAG_DOCUMENT_7                               0
# FLAG_DOCUMENT_8                               0
# FLAG_DOCUMENT_9                               0
# FLAG_DOCUMENT_10                              0
# FLAG_DOCUMENT_11                              0
# FLAG_DOCUMENT_12                              0
# FLAG_DOCUMENT_13                              0
# FLAG_DOCUMENT_14                              0
# FLAG_DOCUMENT_15                              0
# FLAG_DOCUMENT_16                              0
# FLAG_DOCUMENT_17                              0
# FLAG_DOCUMENT_18                              0
# FLAG_DOCUMENT_19                              0
# FLAG_DOCUMENT_20                              0
# FLAG_DOCUMENT_21                              0
# AMT_REQ_CREDIT_BUREAU_HOUR                    1
# AMT_REQ_CREDIT_BUREAU_DAY                     0
# AMT_REQ_CREDIT_BUREAU_WEEK                    0
# AMT_REQ_CREDIT_BUREAU_MON                     1
# AMT_REQ_CREDIT_BUREAU_QRT                     0
# AMT_REQ_CREDIT_BUREAU_YEAR                    1
#
#                                                      307509  \
# SK_ID_CURR                                           456254
# TARGET                                                    1
# NAME_CONTRACT_TYPE                               Cash loans
# CODE_GENDER                                               F
# FLAG_OWN_CAR                                              N
# FLAG_OWN_REALTY                                           Y
# CNT_CHILDREN                                              0
# AMT_INCOME_TOTAL                                     171000
# AMT_CREDIT                                           370107
# AMT_ANNUITY                                           20205
# AMT_GOODS_PRICE                                      319500
# NAME_TYPE_SUITE                               Unaccompanied
# NAME_INCOME_TYPE                       Commercial associate
# NAME_EDUCATION_TYPE           Secondary / secondary special
# NAME_FAMILY_STATUS                                  Married
# NAME_HOUSING_TYPE                         House / apartment
# REGION_POPULATION_RELATIVE                         0.005313
# DAYS_BIRTH                                           -11961
# DAYS_EMPLOYED                                         -4786
# DAYS_REGISTRATION                                     -2562
# DAYS_ID_PUBLISH                                        -931
# OWN_CAR_AGE                                             NaN
# FLAG_MOBIL                                                1
# FLAG_EMP_PHONE                                            1
# FLAG_WORK_PHONE                                           0
# FLAG_CONT_MOBILE                                          1
# FLAG_PHONE                                                0
# FLAG_EMAIL                                                0
# OCCUPATION_TYPE                                    Laborers
# CNT_FAM_MEMBERS                                           2
# REGION_RATING_CLIENT                                      2
# REGION_RATING_CLIENT_W_CITY                               2
# WEEKDAY_APPR_PROCESS_START                        WEDNESDAY
# HOUR_APPR_PROCESS_START                                   9
# REG_REGION_NOT_LIVE_REGION                                0
# REG_REGION_NOT_WORK_REGION                                0
# LIVE_REGION_NOT_WORK_REGION                               0
# REG_CITY_NOT_LIVE_CITY                                    1
# REG_CITY_NOT_WORK_CITY                                    1
# LIVE_CITY_NOT_WORK_CITY                                   0
# ORGANIZATION_TYPE                    Business Entity Type 1
# EXT_SOURCE_1                                            NaN
# EXT_SOURCE_2                                       0.514163
# EXT_SOURCE_3                                       0.661024
# APARTMENTS_AVG                                       0.0124
# BASEMENTAREA_AVG                                        NaN
# YEARS_BEGINEXPLUATATION_AVG                          0.9771
# YEARS_BUILD_AVG                                         NaN
# COMMONAREA_AVG                                          NaN
# ELEVATORS_AVG                                           NaN
# ENTRANCES_AVG                                         0.069
# FLOORSMAX_AVG                                        0.0417
# FLOORSMIN_AVG                                           NaN
# LANDAREA_AVG                                            NaN
# LIVINGAPARTMENTS_AVG                                    NaN
# LIVINGAREA_AVG                                       0.0061
# NONLIVINGAPARTMENTS_AVG                                 NaN
# NONLIVINGAREA_AVG                                       NaN
# APARTMENTS_MODE                                      0.0126
# BASEMENTAREA_MODE                                       NaN
# YEARS_BEGINEXPLUATATION_MODE                         0.9772
# YEARS_BUILD_MODE                                        NaN
# COMMONAREA_MODE                                         NaN
# ELEVATORS_MODE                                          NaN
# ENTRANCES_MODE                                        0.069
# FLOORSMAX_MODE                                       0.0417
# FLOORSMIN_MODE                                          NaN
# LANDAREA_MODE                                           NaN
# LIVINGAPARTMENTS_MODE                                   NaN
# LIVINGAREA_MODE                                      0.0063
# NONLIVINGAPARTMENTS_MODE                                NaN
# NONLIVINGAREA_MODE                                      NaN
# APARTMENTS_MEDI                                      0.0125
# BASEMENTAREA_MEDI                                       NaN
# YEARS_BEGINEXPLUATATION_MEDI                         0.9771
# YEARS_BUILD_MEDI                                        NaN
# COMMONAREA_MEDI                                         NaN
# ELEVATORS_MEDI                                          NaN
# ENTRANCES_MEDI                                        0.069
# FLOORSMAX_MEDI                                       0.0417
# FLOORSMIN_MEDI                                          NaN
# LANDAREA_MEDI                                           NaN
# LIVINGAPARTMENTS_MEDI                                   NaN
# LIVINGAREA_MEDI                                      0.0062
# NONLIVINGAPARTMENTS_MEDI                                NaN
# NONLIVINGAREA_MEDI                                      NaN
# FONDKAPREMONT_MODE                                      NaN
# HOUSETYPE_MODE                               block of flats
# TOTALAREA_MODE                                       0.0086
# WALLSMATERIAL_MODE                             Stone, brick
# EMERGENCYSTATE_MODE                                      No
# OBS_30_CNT_SOCIAL_CIRCLE                                  0
# DEF_30_CNT_SOCIAL_CIRCLE                                  0
# OBS_60_CNT_SOCIAL_CIRCLE                                  0
# DEF_60_CNT_SOCIAL_CIRCLE                                  0
# DAYS_LAST_PHONE_CHANGE                                 -322
# FLAG_DOCUMENT_2                                           0
# FLAG_DOCUMENT_3                                           1
# FLAG_DOCUMENT_4                                           0
# FLAG_DOCUMENT_5                                           0
# FLAG_DOCUMENT_6                                           0
# FLAG_DOCUMENT_7                                           0
# FLAG_DOCUMENT_8                                           0
# FLAG_DOCUMENT_9                                           0
# FLAG_DOCUMENT_10                                          0
# FLAG_DOCUMENT_11                                          0
# FLAG_DOCUMENT_12                                          0
# FLAG_DOCUMENT_13                                          0
# FLAG_DOCUMENT_14                                          0
# FLAG_DOCUMENT_15                                          0
# FLAG_DOCUMENT_16                                          0
# FLAG_DOCUMENT_17                                          0
# FLAG_DOCUMENT_18                                          0
# FLAG_DOCUMENT_19                                          0
# FLAG_DOCUMENT_20                                          0
# FLAG_DOCUMENT_21                                          0
# AMT_REQ_CREDIT_BUREAU_HOUR                                0
# AMT_REQ_CREDIT_BUREAU_DAY                                 0
# AMT_REQ_CREDIT_BUREAU_WEEK                                0
# AMT_REQ_CREDIT_BUREAU_MON                                 0
# AMT_REQ_CREDIT_BUREAU_QRT                                 0
# AMT_REQ_CREDIT_BUREAU_YEAR                                0
#
#                                               307510
# SK_ID_CURR                                    456255
# TARGET                                             0
# NAME_CONTRACT_TYPE                        Cash loans
# CODE_GENDER                                        F
# FLAG_OWN_CAR                                       N
# FLAG_OWN_REALTY                                    N
# CNT_CHILDREN                                       0
# AMT_INCOME_TOTAL                              157500
# AMT_CREDIT                                    675000
# AMT_ANNUITY                                  49117.5
# AMT_GOODS_PRICE                               675000
# NAME_TYPE_SUITE                        Unaccompanied
# NAME_INCOME_TYPE                Commercial associate
# NAME_EDUCATION_TYPE                 Higher education
# NAME_FAMILY_STATUS                           Married
# NAME_HOUSING_TYPE                  House / apartment
# REGION_POPULATION_RELATIVE                   0.04622
# DAYS_BIRTH                                    -16856
# DAYS_EMPLOYED                                  -1262
# DAYS_REGISTRATION                              -5128
# DAYS_ID_PUBLISH                                 -410
# OWN_CAR_AGE                                      NaN
# FLAG_MOBIL                                         1
# FLAG_EMP_PHONE                                     1
# FLAG_WORK_PHONE                                    1
# FLAG_CONT_MOBILE                                   1
# FLAG_PHONE                                         1
# FLAG_EMAIL                                         0
# OCCUPATION_TYPE                             Laborers
# CNT_FAM_MEMBERS                                    2
# REGION_RATING_CLIENT                               1
# REGION_RATING_CLIENT_W_CITY                        1
# WEEKDAY_APPR_PROCESS_START                  THURSDAY
# HOUR_APPR_PROCESS_START                           20
# REG_REGION_NOT_LIVE_REGION                         0
# REG_REGION_NOT_WORK_REGION                         0
# LIVE_REGION_NOT_WORK_REGION                        0
# REG_CITY_NOT_LIVE_CITY                             0
# REG_CITY_NOT_WORK_CITY                             1
# LIVE_CITY_NOT_WORK_CITY                            1
# ORGANIZATION_TYPE             Business Entity Type 3
# EXT_SOURCE_1                                 0.73446
# EXT_SOURCE_2                                0.708569
# EXT_SOURCE_3                                0.113922
# APARTMENTS_AVG                                0.0742
# BASEMENTAREA_AVG                              0.0526
# YEARS_BEGINEXPLUATATION_AVG                   0.9881
# YEARS_BUILD_AVG                                  NaN
# COMMONAREA_AVG                                0.0176
# ELEVATORS_AVG                                   0.08
# ENTRANCES_AVG                                  0.069
# FLOORSMAX_AVG                                  0.375
# FLOORSMIN_AVG                                    NaN
# LANDAREA_AVG                                     NaN
# LIVINGAPARTMENTS_AVG                             NaN
# LIVINGAREA_AVG                                0.0791
# NONLIVINGAPARTMENTS_AVG                          NaN
# NONLIVINGAREA_AVG                                  0
# APARTMENTS_MODE                               0.0756
# BASEMENTAREA_MODE                             0.0546
# YEARS_BEGINEXPLUATATION_MODE                  0.9881
# YEARS_BUILD_MODE                                 NaN
# COMMONAREA_MODE                               0.0178
# ELEVATORS_MODE                                0.0806
# ENTRANCES_MODE                                 0.069
# FLOORSMAX_MODE                                 0.375
# FLOORSMIN_MODE                                   NaN
# LANDAREA_MODE                                    NaN
# LIVINGAPARTMENTS_MODE                            NaN
# LIVINGAREA_MODE                               0.0824
# NONLIVINGAPARTMENTS_MODE                         NaN
# NONLIVINGAREA_MODE                                 0
# APARTMENTS_MEDI                               0.0749
# BASEMENTAREA_MEDI                             0.0526
# YEARS_BEGINEXPLUATATION_MEDI                  0.9881
# YEARS_BUILD_MEDI                                 NaN
# COMMONAREA_MEDI                               0.0177
# ELEVATORS_MEDI                                  0.08
# ENTRANCES_MEDI                                 0.069
# FLOORSMAX_MEDI                                 0.375
# FLOORSMIN_MEDI                                   NaN
# LANDAREA_MEDI                                    NaN
# LIVINGAPARTMENTS_MEDI                            NaN
# LIVINGAREA_MEDI                               0.0805
# NONLIVINGAPARTMENTS_MEDI                         NaN
# NONLIVINGAREA_MEDI                                 0
# FONDKAPREMONT_MODE                               NaN
# HOUSETYPE_MODE                        block of flats
# TOTALAREA_MODE                                0.0718
# WALLSMATERIAL_MODE                             Panel
# EMERGENCYSTATE_MODE                               No
# OBS_30_CNT_SOCIAL_CIRCLE                           0
# DEF_30_CNT_SOCIAL_CIRCLE                           0
# OBS_60_CNT_SOCIAL_CIRCLE                           0
# DEF_60_CNT_SOCIAL_CIRCLE                           0
# DAYS_LAST_PHONE_CHANGE                          -787
# FLAG_DOCUMENT_2                                    0
# FLAG_DOCUMENT_3                                    1
# FLAG_DOCUMENT_4                                    0
# FLAG_DOCUMENT_5                                    0
# FLAG_DOCUMENT_6                                    0
# FLAG_DOCUMENT_7                                    0
# FLAG_DOCUMENT_8                                    0
# FLAG_DOCUMENT_9                                    0
# FLAG_DOCUMENT_10                                   0
# FLAG_DOCUMENT_11                                   0
# FLAG_DOCUMENT_12                                   0
# FLAG_DOCUMENT_13                                   0
# FLAG_DOCUMENT_14                                   0
# FLAG_DOCUMENT_15                                   0
# FLAG_DOCUMENT_16                                   0
# FLAG_DOCUMENT_17                                   0
# FLAG_DOCUMENT_18                                   0
# FLAG_DOCUMENT_19                                   0
# FLAG_DOCUMENT_20                                   0
# FLAG_DOCUMENT_21                                   0
# AMT_REQ_CREDIT_BUREAU_HOUR                         0
# AMT_REQ_CREDIT_BUREAU_DAY                          0
# AMT_REQ_CREDIT_BUREAU_WEEK                         0
# AMT_REQ_CREDIT_BUREAU_MON                          2
# AMT_REQ_CREDIT_BUREAU_QRT                          0
# AMT_REQ_CREDIT_BUREAU_YEAR                         1

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
m = RandomForestClassifier(n_jobs=-1)
m.fit(df_raw.drop('TARGET', axis=1), df_raw['TARGET'])
# Out:
# C:\Users\BPS\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-71301eac6a54> in <module>
#       1 m = RandomForestClassifier(n_jobs=-1)
# ----> 2 m.fit(df_raw.drop('TARGET', axis=1), df_raw['TARGET'])
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Cash loans'
